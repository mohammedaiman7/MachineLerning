# %%
import pandas as pd

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from sklearn import linear_model

# %%
df=pd.read_csv("homeprices1.csv")
df
df.area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
# %matplotlib inline
plt.xlabel("area(sqr ft)")
plt.ylabel("price(US$)")
plt.scatter(df.area,df.price,color="red",)

# %%
reg=linear_model.LinearRegression()
reg.fit(df[['area']],df.price)
# Out:
# LinearRegression()

# %%
df[['area']]
# Out:
#    area
# 0  2600
# 1  3000
# 2  3200
# 3  3600
# 4  4000

# %%
reg.predict([[3300]])
# Out:
# C:\Users\moham\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
df.area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
df.area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
x=np.array([5,15,25,35,45,55]).reshape((-1,1))
x
# Out:
# array([[ 5],
#        [15],
#        [25],
#        [35],
#        [45],
#        [55]])

# %%
y=np.array([5,20,14,32,22,38])
y
# Out:
# array([ 5, 20, 14, 32, 22, 38])

# %%
model=linear_model.LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.predict(x)
# Out:
# array([ 8.33333333, 13.73333333, 19.13333333, 24.53333333, 29.93333333,
#        35.33333333])

# %%
df.area
# Out:
# 0    2600
# 1    3000
# 2    3200
# 3    3600
# 4    4000
# Name: area, dtype: int64

# %%
df
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
reg.predict([[4000]])
# Out:
# C:\Users\moham\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([723767.12328767])

# %% [markdown]
# ##

# %%
cd = pd.read_csv("canada_per_capita_income.csv")
cd
# Out:
#     year  per_capita_income
# 0   1970        3399.299037
# 1   1971        3768.297935
# 2   1972        4251.175484
# 3   1973        4804.463248
# 4   1974        5576.514583
# 5   1975        5998.144346
# 6   1976        7062.131392
# 7   1977        7100.126170
# 8   1978        7247.967035
# 9   1979        7602.912681
# 10  1980        8355.968120
# 11  1981        9434.390652
# 12  1982        9619.438377
# 13  1983       10416.536590
# 14  1984       10790.328720
# 15  1985       11018.955850
# 16  1986       11482.891530
# 17  1987       12974.806620
# 18  1988       15080.283450
# 19  1989       16426.725480
# 20  1990       16838.673200
# 21  1991       17266.097690
# 22  1992       16412.083090
# 23  1993       15875.586730
# 24  1994       15755.820270
# 25  1995       16369.317250
# 26  1996       16699.826680
# 27  1997       17310.757750
# 28  1998       16622.671870
# 29  1999       17581.024140
# 30  2000       18987.382410
# 31  2001       18601.397240
# ...

# %%
reg.coef_
# Out:
# array([135.78767123])

# %%
reg.intercept_
# Out:
# 180616.43835616432

# %%
hap=pd.read_csv("home_area_prices.csv")
import math
median_bedrooms=math.floor(hap.bedrooms.median())
median_bedrooms
# Out:
# 3

# %%
hap.bedrooms=hap.bedrooms.fillna(median_bedrooms)

# %%
hap
# Out:
#    area  bedrooms  age   price
# 0  2600       3.0   20  550000
# 1  3000       4.0   15  565000
# 2  3200       3.0   18  610000
# 3  3600       3.0   30  595000
# 4  4000       5.0    8  760000

# %%
hreg=linear_model.LinearRegression()
hreg.fit(hap[['area','bedrooms','age']],hap.price)
# Out:
# LinearRegression()

# %%
hreg.coef_
# Out:
# array([   137.25, -26025.  ,  -6825.  ])

# %%
hreg.intercept_
# Out:
# 383724.99999999977

# %%
hreg.predict([[3000,3,40]])
# Out:
# C:\Users\moham\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([444400.])

# %%
hreg.predict([[2500,4,5]])
# Out:
# C:\Users\moham\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([588625.])

# %%
hreg.predict([[2500,3,5]])
# Out:
# C:\Users\moham\AppData\Roaming\Python\Python311\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([614650.])
